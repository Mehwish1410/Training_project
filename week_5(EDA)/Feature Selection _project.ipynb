# %% [markdown]
# Demographic Distrubution Dataset

# %%
import pandas as pd
data = pd.read_csv('stats.csv')
data
# Out:
#        ID                PROVINCE      DISTRICT   SEX  AGE  TOTAL POPULATION  \
# 0   17629  AZAD JUMMU AND KASHMIR  Muzaffarabad  Both   15            136397
# 1   17632  AZAD JUMMU AND KASHMIR  Hattian Bala  Both   30             81158
# 2   17636  AZAD JUMMU AND KASHMIR         Nelum  Both   50             49224
# 3   17642  AZAD JUMMU AND KASHMIR        Mirpur  Both   15             68954
# 4   17646  AZAD JUMMU AND KASHMIR       Bhimber  Both   35             32482
# ..    ...                     ...           ...   ...  ...               ...
# 69  27960                   SINDH     Shikarpur  Both   60               772
# 70  27965                   SINDH         Malir  Both   20            290780
# 71  27966                   SINDH      Khairpur  Both   25            233631
# 72  27967                   SINDH         Badin  Both   30            200776
# 73  27968                   SINDH        Ghotki  Both   35            151292
#
# ...

# %%
data.drop(columns=['PROVINCE'], inplace=True)

# %%
data
# Out:
#        ID      DISTRICT   SEX  AGE  TOTAL POPULATION  NEVER EDUCATED  \
# 0   17629  Muzaffarabad  Both   15            136397          124005
# 1   17632  Hattian Bala  Both   30             81158           10632
# 2   17636         Nelum  Both   50             49224            1845
# 3   17642        Mirpur  Both   15             68954           67265
# 4   17646       Bhimber  Both   35             32482            2540
# ..    ...           ...   ...  ...               ...             ...
# 69  27960     Shikarpur  Both   60               772              34
# 70  27965         Malir  Both   20            290780          156850
# 71  27966      Khairpur  Both   25            233631           57686
# 72  27967         Badin  Both   30            200776           20564
# 73  27968        Ghotki  Both   35            151292            7629
#
#     EDUCATED   JOBS  JOBLESS  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0      12045   4015     8030          NaN          NaN          NaN
# ...

# %%
data.drop(columns=['DISTRICT'], inplace=True)

# %%
data
# Out:
#        ID   SEX  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  \
# 0   17629  Both   15            136397          124005     12045   4015
# 1   17632  Both   30             81158           10632     68531  22844
# 2   17636  Both   50             49224            1845     40769  13590
# 3   17642  Both   15             68954           67265      1586    529
# 4   17646  Both   35             32482            2540     29504   9835
# ..    ...   ...  ...               ...             ...       ...    ...
# 69  27960  Both   60               772              34       436    145
# 70  27965  Both   20            290780          156850    131723  43908
# 71  27966  Both   25            233631           57686    172670  57557
# 72  27967  Both   30            200776           20564    175912  58637
# 73  27968  Both   35            151292            7629    138765  46255
#
#     JOBLESS  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0      8030          NaN          NaN          NaN
# ...

# %%
data.isna().sum().sum()
# Out:
# np.int64(222)

# %%
data
# Out:
#        ID   SEX  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  \
# 0   17629  Both   15            136397          124005     12045   4015
# 1   17632  Both   30             81158           10632     68531  22844
# 2   17636  Both   50             49224            1845     40769  13590
# 3   17642  Both   15             68954           67265      1586    529
# 4   17646  Both   35             32482            2540     29504   9835
# ..    ...   ...  ...               ...             ...       ...    ...
# 69  27960  Both   60               772              34       436    145
# 70  27965  Both   20            290780          156850    131723  43908
# 71  27966  Both   25            233631           57686    172670  57557
# 72  27967  Both   30            200776           20564    175912  58637
# 73  27968  Both   35            151292            7629    138765  46255
#
#     JOBLESS  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0      8030          NaN          NaN          NaN
# ...

# %%
data.drop(columns=['SEX'],inplace=True)

# %%
data
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
Q1 = data['TOTAL POPULATION'].quantile(0.25)
Q3 = data['TOTAL POPULATION'].quantile(0.75)
IQR = Q3-Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
cleadf = data[(data['TOTAL POPULATION']>lower) & (data['TOTAL POPULATION']<upper)]
cleadf
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# 5   17651   60             15993             600     13606   4535     9071
# 6   17656   20             56231           23912     31665  10555    21110
# ..    ...  ...               ...             ...       ...    ...      ...
# 65  26419   25              1364             614       735    245      490
# 66  26420   30              1293             263      1017    339      678
# 67  27958   50              1267              45       974    325      649
# 68  27959   55               873              24       579    193      386
# 69  27960   60               772              34       436    145      291
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %%
data['EDUCATED_binned'] =pd.cut(data['EDUCATED'],bins=3, labels=['less','in_between','more'])

# %%
data
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12 EDUCATED_binned
# ...

# %%
data=data.drop(columns=['EDUCATED_binned'],axis=1)

# %%
data
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %% [markdown]
# DATA TRANSFRMATION

# %%
from sklearn.preprocessing import PolynomialFeatures
pf =PolynomialFeatures(degree=2, include_bias=False)
p_data = pf.fit_transform(data['JOBLESS'].values.reshape(-1,1))
p_data
p_df = pd.DataFrame(p_data, columns=['T_JOBLESS','T2_JOBLESS'])

# %%
p_df
# Out:
#     T_JOBLESS    T2_JOBLESS
# 0      8030.0  6.448090e+07
# 1     45687.0  2.087302e+09
# 2     27179.0  7.386980e+08
# 3      1057.0  1.117249e+06
# 4     19669.0  3.868696e+08
# ..        ...           ...
# 69      291.0  8.468100e+04
# 70    87815.0  7.711474e+09
# 71   115113.0  1.325100e+10
# 72   117275.0  1.375343e+10
# 73    92510.0  8.558100e+09
#
# [74 rows x 2 columns]

# %% [markdown]
# DATA SCALING

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
scaled_data = ss.fit_transform(data) 
scaled_data
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\extmath.py:1137: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\extmath.py:1142: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\extmath.py:1162: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# array([[-8.76127414e-01, -1.47369892e+00,  2.03357697e+00,
#          4.46921456e+00, -1.78849970e-01, -1.78852782e-01,
#         -1.78848564e-01,             nan,             nan,
#                     nan],
#        [-8.75264973e-01, -6.85358774e-01,  9.87122237e-01,
#          4.82612888e-02,  1.40665213e+00,  1.40667541e+00,
# ...

# %%
scaled_df = pd.DataFrame(scaled_data, columns=data.columns, index=data.index)
scaled_df
# Out:
#           ID       AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED      JOBS  \
# 0  -0.876127 -1.473699          2.033577        4.469215 -0.178850 -0.178853
# 1  -0.875265 -0.685359          0.987122        0.048261  1.406652  1.406675
# 2  -0.874115  0.365761          0.382160       -0.294386  0.627402  0.627426
# 3  -0.872390 -1.473699          0.755928        2.256652 -0.472423 -0.472397
# 4  -0.871240 -0.422579          0.064998       -0.267284  0.311206  0.311230
# ..       ...       ...               ...             ...       ...       ...
# 69  2.093832  0.891322         -0.535721       -0.365005 -0.504702 -0.504733
# 70  2.095269 -1.210919          4.958228        5.749998  3.180385  3.180406
# 71  2.095557 -0.948139          3.875590        1.883121  4.329723  4.329743
# 72  2.095844 -0.685359          3.253181        0.435557  4.420723  4.420686
# 73  2.096132 -0.422579          2.315750       -0.068840  3.378046  3.378039
#
# ...

# %%
data
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %%
data
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %%
s_col = ss.fit_transform(data['EDUCATED'].values.reshape(-1,1))
data['s_EDUCATED']=s_col

# %%
data
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12  s_EDUCATED
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(data['NEVER EDUCATED'])
# Out:
# (array([64.,  4.,  0.,  3.,  1.,  0.,  0.,  1.,  0.,  1.]),
#  array([7.000000e+00, 1.569130e+04, 3.137560e+04, 4.705990e+04,
#         6.274420e+04, 7.842850e+04, 9.411280e+04, 1.097971e+05,
#         1.254814e+05, 1.411657e+05, 1.568500e+05]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
transformed_col = np.log1p(data['NEVER EDUCATED'])
plt.hist(transformed_col)
# Out:
# (array([ 5.,  8.,  9., 11., 11., 11.,  4.,  8.,  4.,  3.]),
#  array([ 2.07944154,  3.06780255,  4.05616355,  5.04452456,  6.03288556,
#          7.02124657,  8.00960757,  8.99796857,  9.98632958, 10.97469058,
#         11.96305159]),
#  <BarContainer object of 10 artists>)

# %%
data['NEVER EDUCATED'].std()
# Out:
# np.float64(25819.518804114243)

# %%
transformed_col.std()
# Out:
# np.float64(2.4633262767984268)

# %%
data
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12  s_EDUCATED
# ...

# %%
from scipy.stats import boxcox
lem =boxcox(data['EDUCATED'], lmbda=None)[1]
lem
# Out:
# np.float64(0.03171483086750485)

# %%
t_data = boxcox(data['EDUCATED'],lmbda=lem)

# %%
plt.hist(data['EDUCATED'])
# Out:
# (array([55., 11.,  3.,  1.,  0.,  0.,  0.,  2.,  0.,  2.]),
#  array([6.100000e+01, 1.764610e+04, 3.523120e+04, 5.281630e+04,
#         7.040140e+04, 8.798650e+04, 1.055716e+05, 1.231567e+05,
#         1.407418e+05, 1.583269e+05, 1.759120e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(t_data)
# Out:
# (array([ 2.,  9.,  6., 12.,  5., 12., 10., 11.,  3.,  4.]),
#  array([ 4.39088851,  5.42348263,  6.45607675,  7.48867087,  8.52126499,
#          9.55385911, 10.58645323, 11.61904735, 12.65164147, 13.68423559,
#         14.71682971]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import QuantileTransformer
qt = QuantileTransformer(output_distribution='normal', random_state=0)
t_data =qt.fit_transform(data)
t_df = pd.DataFrame(t_data, columns=data.columns, index=data.index)
t_df
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_data.py:2785: UserWarning: n_quantiles (1000) is greater than the total number of samples (74). n_quantiles is set to n_samples.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1634: RuntimeWarning: All-NaN slice encountered
#   return fnb._ureduce(a,
#           ID       AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED      JOBS  \
# 0  -5.199338 -5.199338          1.600043        2.205811  0.405743  0.405743
# 1  -2.205811 -0.481534          1.390479        0.976600  1.600043  1.600043
# 2  -1.920502  0.242724          1.033500        0.520465  1.305329  1.305329
# 3  -1.738108 -5.199338          1.305329        1.920502 -0.405743 -0.405743
# 4  -1.600043 -0.242724          0.729406        0.600842  0.976600  0.976600
# ..       ...       ...               ...             ...       ...       ...
# ...

# %%
data['NEVER EDUCATED']=pd.cut(data['NEVER EDUCATED'], bins=3, labels=['small','medium','large'])

# %%
data
# Out:
#        ID  AGE  TOTAL POPULATION NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          large     12045   4015     8030
# 1   17632   30             81158          small     68531  22844    45687
# 2   17636   50             49224          small     40769  13590    27179
# 3   17642   15             68954         medium      1586    529     1057
# 4   17646   35             32482          small     29504   9835    19669
# ..    ...  ...               ...            ...       ...    ...      ...
# 69  27960   60               772          small       436    145      291
# 70  27965   20            290780          large    131723  43908    87815
# 71  27966   25            233631         medium    172670  57557   115113
# 72  27967   30            200776          small    175912  58637   117275
# 73  27968   35            151292          small    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12  s_EDUCATED
# ...

# %% [markdown]
# FEATURE SELECTION
#
# 1. Variance Threshold

# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

# %%
df = pd.read_csv('stats.csv')
df
# Out:
#        ID                PROVINCE      DISTRICT   SEX  AGE  TOTAL POPULATION  \
# 0   17629  AZAD JUMMU AND KASHMIR  Muzaffarabad  Both   15            136397
# 1   17632  AZAD JUMMU AND KASHMIR  Hattian Bala  Both   30             81158
# 2   17636  AZAD JUMMU AND KASHMIR         Nelum  Both   50             49224
# 3   17642  AZAD JUMMU AND KASHMIR        Mirpur  Both   15             68954
# 4   17646  AZAD JUMMU AND KASHMIR       Bhimber  Both   35             32482
# ..    ...                     ...           ...   ...  ...               ...
# 69  27960                   SINDH     Shikarpur  Both   60               772
# 70  27965                   SINDH         Malir  Both   20            290780
# 71  27966                   SINDH      Khairpur  Both   25            233631
# 72  27967                   SINDH         Badin  Both   30            200776
# 73  27968                   SINDH        Ghotki  Both   35            151292
#
# ...

# %%
df =df.drop_duplicates()

# %%
df.drop(columns=['SEX'],inplace=True)
df.drop(columns=['DISTRICT'],inplace=True)
df.drop(columns=['PROVINCE'],inplace=True)

# %%
df
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS  \
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %%
X = df.iloc[:, : 6]

# %%
X
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS
# 0   17629   15            136397          124005     12045   4015
# 1   17632   30             81158           10632     68531  22844
# 2   17636   50             49224            1845     40769  13590
# 3   17642   15             68954           67265      1586    529
# 4   17646   35             32482            2540     29504   9835
# ..    ...  ...               ...             ...       ...    ...
# 69  27960   60               772              34       436    145
# 70  27965   20            290780          156850    131723  43908
# 71  27966   25            233631           57686    172670  57557
# 72  27967   30            200776           20564    175912  58637
# 73  27968   35            151292            7629    138765  46255
#
# [74 rows x 6 columns]

# %%
y=df.iloc[:,6]

# %%
y
# Out:
# 0       8030
# 1      45687
# 2      27179
# 3       1057
# 4      19669
#        ...
# 69       291
# 70     87815
# 71    115113
# 72    117275
# 73     92510
# Name: JOBLESS, Length: 74, dtype: int64

# %%
df = df.dropna(axis=1, how='any')

# %%
df
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
# [74 rows x 7 columns]

# %%
selector = VarianceThreshold(threshold=0.7)
X_selected = selector.fit_transform(X)
S_features = X.columns[selector.get_support()].tolist()
S_features
# Out:
# ['ID', 'AGE', 'TOTAL POPULATION', 'NEVER EDUCATED', 'EDUCATED', 'JOBS']

# %%
X_selected = pd.DataFrame(X_selected,columns=S_features)
X_selected
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS
# 0   17629   15            136397          124005     12045   4015
# 1   17632   30             81158           10632     68531  22844
# 2   17636   50             49224            1845     40769  13590
# 3   17642   15             68954           67265      1586    529
# 4   17646   35             32482            2540     29504   9835
# ..    ...  ...               ...             ...       ...    ...
# 69  27960   60               772              34       436    145
# 70  27965   20            290780          156850    131723  43908
# 71  27966   25            233631           57686    172670  57557
# 72  27967   30            200776           20564    175912  58637
# 73  27968   35            151292            7629    138765  46255
#
# [74 rows x 6 columns]

# %% [raw]
# CORRELATION COEFFICIENT

# %%
df
# Out:
#        ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED   JOBS  JOBLESS
# 0   17629   15            136397          124005     12045   4015     8030
# 1   17632   30             81158           10632     68531  22844    45687
# 2   17636   50             49224            1845     40769  13590    27179
# 3   17642   15             68954           67265      1586    529     1057
# 4   17646   35             32482            2540     29504   9835    19669
# ..    ...  ...               ...             ...       ...    ...      ...
# 69  27960   60               772              34       436    145      291
# 70  27965   20            290780          156850    131723  43908    87815
# 71  27966   25            233631           57686    172670  57557   115113
# 72  27967   30            200776           20564    175912  58637   117275
# 73  27968   35            151292            7629    138765  46255    92510
#
# [74 rows x 7 columns]

# %%
df.corr()
# Out:
#                         ID       AGE  TOTAL POPULATION  NEVER EDUCATED  \
# ID                1.000000 -0.032880          0.283796        0.114081
# AGE              -0.032880  1.000000         -0.403281       -0.443066
# TOTAL POPULATION  0.283796 -0.403281          1.000000        0.781802
# NEVER EDUCATED    0.114081 -0.443066          0.781802        1.000000
# EDUCATED          0.337926 -0.286057          0.902574        0.438234
# JOBS              0.337923 -0.286057          0.902576        0.438238
# JOBLESS           0.337927 -0.286056          0.902573        0.438233
#
#                   EDUCATED      JOBS   JOBLESS
# ID                0.337926  0.337923  0.337927
# AGE              -0.286057 -0.286057 -0.286056
# TOTAL POPULATION  0.902574  0.902576  0.902573
# NEVER EDUCATED    0.438234  0.438238  0.438233
# EDUCATED          1.000000  1.000000  1.000000
# JOBS              1.000000  1.000000  1.000000
# JOBLESS           1.000000  1.000000  1.000000

# %% [raw]
# CHI-2 METHOD

# %%
from sklearn.feature_selection import chi2,SelectKBest
import pandas as pd

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
#binning
X['EDUCATED']=pd.cut(X['EDUCATED'], bins=3, labels=['small','medium','large'])
X['NEVER EDUCATED']=pd.cut(X['NEVER EDUCATED'], bins=3, labels=['small','medium','large'])
X['JOBS']=pd.cut(X['JOBS'], bins=3, labels=['small','medium','large'])
X['TOTAL POPULATION']=pd.cut(X['TOTAL POPULATION'], bins=3, labels=['small','medium','large'])
X['AGE']=pd.cut(X['AGE'], bins=3, labels=['small','medium','large'])
X['ID']=pd.cut(X['ID'], bins=3, labels=['small','medium','large'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11144\1300945051.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['EDUCATED']=pd.cut(X['EDUCATED'], bins=3, labels=['small','medium','large'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_11144\1300945051.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['NEVER EDUCATED']=pd.cut(X['NEVER EDUCATED'], bins=3, labels=['small','medium','large'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_11144\1300945051.py:4: SettingWithCopyWarning:
# ...

# %%
X
# Out:
#        ID     AGE TOTAL POPULATION NEVER EDUCATED EDUCATED    JOBS
# 0   small   small           medium          large    small   small
# 1   small   small            small          small   medium  medium
# 2   small  medium            small          small    small   small
# 3   small   small            small         medium    small   small
# 4   small   small            small          small    small   small
# ..    ...     ...              ...            ...      ...     ...
# 69  large   large            small          small    small   small
# 70  large   small            large          large    large   large
# 71  large   small            large         medium    large   large
# 72  large   small            large          small    large   large
# 73  large   small           medium          small    large   large
#
# [74 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X['TOTAL POPULATION']=le.fit_transform(X['TOTAL POPULATION'])
X['NEVER EDUCATED']=le.fit_transform(X['NEVER EDUCATED'])
X['EDUCATED']=le.fit_transform(X['EDUCATED'])
X['JOBS']=le.fit_transform(X['JOBS'])
X['ID']=le.fit_transform(X['ID'])
X['AGE']=le.fit_transform(X['AGE'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11144\822435910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['TOTAL POPULATION']=le.fit_transform(X['TOTAL POPULATION'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_11144\822435910.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['NEVER EDUCATED']=le.fit_transform(X['NEVER EDUCATED'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_11144\822435910.py:5: SettingWithCopyWarning:
# ...

# %%
X
# Out:
#     ID  AGE  TOTAL POPULATION  NEVER EDUCATED  EDUCATED  JOBS
# 0    2    2                 1               0         2     2
# 1    2    2                 2               2         1     1
# 2    2    1                 2               2         2     2
# 3    2    2                 2               1         2     2
# 4    2    2                 2               2         2     2
# ..  ..  ...               ...             ...       ...   ...
# 69   0    0                 2               2         2     2
# 70   0    2                 0               0         0     0
# 71   0    2                 0               1         0     0
# 72   0    2                 0               2         0     0
# 73   0    2                 1               2         0     0
#
# [74 rows x 6 columns]

# %%
from sklearn.feature_selection import chi2,SelectKBest
select= SelectKBest(chi2,k=3)
selected_data = select.fit_transform(X,y)
s_features = X.columns[select.get_support()].tolist()
s_features
slected_df = pd.DataFrame(selected_data,columns=s_features)

# %%
slected_df
# Out:
#     ID  AGE  JOBS
# 0    2    2     2
# 1    2    2     1
# 2    2    1     2
# 3    2    2     2
# 4    2    2     2
# ..  ..  ...   ...
# 69   0    0     2
# 70   0    2     0
# 71   0    2     0
# 72   0    2     0
# 73   0    2     0
#
# [74 rows x 3 columns]
